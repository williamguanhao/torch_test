# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
import random
import matplotlib.pyplot as plt
import time
from PyPDF2 import PdfReader
import re
import os
import math
from typing import List

# %%
# dataset loader
class CharDataset(Dataset):

    def __init__(self, words, chars, max_word_length):
        self.words = words
        self.chars = chars
        self.max_word_length = max_word_length
        self.stoi = {ch:i+1 for i,ch in enumerate(chars)}
        self.stoi['.'] = 0
        self.itos = {i:s for s,i in self.stoi.items()} # inverse mapping
        self.itos[0] = '.'

    def __len__(self):
        return len(self.words)

    def contains(self, word):
        return word in self.words

    def get_vocab_size(self):
        return len(self.chars) + 1 # all the possible characters and special 0 token

    def get_output_length(self):
        return self.max_word_length + 1 # <START> token followed by words

    def encode(self, word):
        ix = torch.tensor([self.stoi[w] for w in word], dtype=torch.long)
        return ix

    def decode(self, ix):
        word = ''.join(self.itos[i] for i in ix)
        return word

    def __getitem__(self, idx):
        word = self.words[idx]
        ix = self.encode(word)
        x = torch.zeros(self.max_word_length + 1, dtype=torch.long)
        y = torch.zeros(self.max_word_length + 1, dtype=torch.long)
        x[1:1+len(ix)] = ix
        y[:len(ix)] = ix
        y[len(ix)+1:] = -1 # index -1 will mask the loss at the inactive locations
        return x, y

def create_datasets(input_file):

    # preprocessing of the input text file
    reader = PdfReader(input_file)
    text = ''
    for i in range(len(reader.pages)):
        page = reader.pages[i]
        text = text + page.extract_text()
    clean_text = re.sub(r'[^\w]', ' ', text).lower()
    clean_text = re.sub(r'_', ' ', clean_text)
    words = clean_text.split()
    chars = sorted(list(set(clean_text))) # all the possible characters
    number_unique_char =len(chars)
    max_word_length = max(len(w) for w in words)
    print(f"number of examples in the dataset: {len(words)}")
    print(f"max word length: {max_word_length}")
    print(f"number of unique characters in the vocabulary: {number_unique_char}")
    print("vocabulary:")
    print(''.join(chars))

    # partition the input data into a training and the test set
    test_set_size = min(1000, int(len(words) * 0.1)) # 10% of the training set, or up to 1000 examples
    rp = torch.randperm(len(words)).tolist()
    train_words = [words[i] for i in rp[:-test_set_size]]
    test_words = [words[i] for i in rp[-test_set_size:]]
    print(f"split up the dataset into {len(train_words)} training examples and {len(test_words)} test examples")

    # wrap in dataset objects
    train_dataset = CharDataset(train_words, chars, max_word_length)
    test_dataset = CharDataset(test_words, chars, max_word_length)

    return train_dataset, test_dataset

class InfiniteDataLoader:
    """
    this is really hacky and I'm not proud of it, but there doesn't seem to be
    a better way in PyTorch to just create an infinite dataloader?
    """

    def __init__(self, dataset, **kwargs):
        train_sampler = torch.utils.data.RandomSampler(dataset, replacement=True, num_samples=int(1e10))
        self.train_loader = DataLoader(dataset, sampler=train_sampler, **kwargs)
        self.data_iter = iter(self.train_loader)

    def next(self):
        try:
            batch = next(self.data_iter)
        except StopIteration: # this will technically only happen after 1e10 samples... (i.e. basically never)
            self.data_iter = iter(self.train_loader)
            batch = next(self.data_iter)
        return batch

# %%
train_dataset, test_dataset = create_datasets('ISDA.pdf')
# Out:
# number of examples in the dataset: 6922
# max word length: 17
# number of unique characters in the vocabulary: 37
# vocabulary:
#  0123456789abcdefghijklmnopqrstuvwxyz
# split up the dataset into 6230 training examples and 692 test examples

# %%
@torch.no_grad()
def generate(model, idx, max_new_tokens, temperature=1.0, do_sample=False, top_k=None):
    """
    Take a conditioning sequence of indices idx (LongTensor of shape (b,t)) and complete
    the sequence max_new_tokens times, feeding the predictions back into the model each time.
    Most likely you'll want to make sure to be in model.eval() mode of operation for this.
    """
    block_size = 8
    for _ in range(max_new_tokens):
        # if the sequence context is growing too long we must crop it at block_size
        idx_cond = idx if idx.size(1) <= block_size else idx[:, -block_size:]
        # forward the model to get the logits for the index in the sequence
        logits, _ = model(idx_cond)
        # pluck the logits at the final step and scale by desired temperature
        logits = logits[:, -1, :] / temperature
        # optionally crop the logits to only the top k options
        if top_k is not None:
            v, _ = torch.topk(logits, top_k)
            logits[logits < v[:, [-1]]] = -float('Inf')
        # apply softmax to convert logits to (normalized) probabilities
        probs = F.softmax(logits, dim=-1)
        # either sample from the distribution or take the most likely element
        if do_sample:
            idx_next = torch.multinomial(probs, num_samples=1)
        else:
            _, idx_next = torch.topk(probs, k=1, dim=-1)
        # append sampled index to the running sequence and continue
        idx = torch.cat((idx, idx_next), dim=1)

    return idx

def print_samples(model, dataset, device, num=10):
    """ samples from the model and pretty prints the decoded samples """
    X_init = torch.zeros(num, 1, dtype=torch.long, device=device)
    top_k = 10
    steps = dataset.get_output_length() - 1 # -1 because we already start with <START> token (index 0)
    X_samp = generate(model, X_init, steps, top_k=top_k, do_sample=True).to(device)
    train_samples, test_samples, new_samples = [], [], []
    for i in range(X_samp.size(0)):
        # get the i'th row of sampled integers, as python list
        row = X_samp[i, 1:].tolist() # note: we need to crop out the first <START> token
        # token 0 is the <STOP> token, so we crop the output sequence at that point
        crop_index = row.index(0) if 0 in row else len(row)
        row = row[:crop_index]
        word_samp = train_dataset.decode(row)
        # separately track samples that we have and have not seen before
        if train_dataset.contains(word_samp):
            train_samples.append(word_samp)
        elif test_dataset.contains(word_samp):
            test_samples.append(word_samp)
        else:
            new_samples.append(word_samp)
    print('-'*80)
    for lst, desc in [(train_samples, 'in train'), (test_samples, 'in test'), (new_samples, 'new')]:
        print(f"{len(lst)} samples that are {desc}:")
        for word in lst:
            print(word)
    print('-'*80)

@torch.inference_mode()
def evaluate(model, dataset, device, batch_size=50, max_batches=None):
    model.eval()
    loader = DataLoader(dataset, shuffle=True, batch_size=batch_size, num_workers=0)
    losses = []
    for i, batch in enumerate(loader):
        batch = [t.to(device) for t in batch]
        X, Y = batch
        logits, loss = model(X, Y)
        losses.append(loss.item())
        if max_batches is not None and i >= max_batches:
            break
    mean_loss = torch.tensor(losses).mean().item()
    model.train() # reset model back to training mode
    return mean_loss

# %%
from dataclasses import dataclass
@dataclass
class ModelConfig:
    block_size: int = None # length of the input sequences of integers
    vocab_size: int = None # the input integers are in range [0 .. vocab_size -1]
    # parameters below control the sizes of each model slightly differently
    n_layer: int = 4
    n_embd: int = 64
    n_embd2: int = 64
    n_head: int = 4
    head_size: int = 16

# %%
# init model
vocab_size = train_dataset.get_vocab_size()
block_size = train_dataset.get_output_length()
config = ModelConfig(vocab_size=vocab_size+1, block_size=128,
                       n_layer=4, n_head=4,
                       n_embd=64, head_size=16, n_embd2=64)

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, n_embd, head_size, block_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))
        self.head_size = head_size

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)   # (B,T,head_size)
        q = self.query(x) # (B,T,head_size)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2, -1) * (1.0 / math.sqrt(self.head_size)) # (B,T,head_size) @ (B,head_size,T) -> (B,T,T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B,T,T)
        wei = F.softmax(wei, dim=-1) # (B,T,T)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,head_size)
        out = wei @ v # (B,T,T) @ (B,T,head_size) -> (B,T,head_size)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size, n_embd, block_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(n_embd, head_size, block_size) for _ in range(num_heads)])

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)  # (B, T, num_heads * head_size)
        return out
class FeedFoward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU()
        )
    def foward(self, x):
        return self.net(x)

class Transformer_simple(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.token_embedding = nn.Embedding(config.vocab_size, config.n_embd)
        self.position_embedding = nn.Embedding(config.block_size, config.n_embd)
        self.sa_heads = MultiHeadAttention(config.n_head, config.head_size, config.n_embd, config.block_size)
        self.ffwd = FeedFoward(config.n_embd)
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        device = idx.device
        tok_emb = self.token_embedding(idx) # (B,T,n_embd)
        pos_emb = self.position_embedding(torch.arange(T, device=device)) # (T,n_embd)
        x = tok_emb + pos_emb # (B,T,n_embd)
        x = self.sa_heads(x) # (B,T,n_embd)
        x = self.ffwd(x)
        logits = self.lm_head(x) # (B,T,vocab_size)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
        return logits, loss
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -config.block_size:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :] # (B,C)
            probs = F.softmax(logits, dim=-1) # (B,C)
            idx_next = torch.multinomial(probs, num_samples=1) # (B,1)
            idx = torch.cat((idx, idx_next), dim=1) # (B,T+1)
        return idx

# %%
# init model
vocab_size = train_dataset.get_vocab_size()
block_size = train_dataset.get_output_length()
config = ModelConfig(vocab_size=vocab_size+1, block_size=block_size,
                       n_layer=6, n_head=6,
                       n_embd=384, head_size=16, n_embd2=64)
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, n_embd, head_size, block_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))
        self.head_size = head_size

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)   # (B,T,head_size)
        q = self.query(x) # (B,T,head_size)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2, -1) * (1.0 / math.sqrt(self.head_size)) # (B,T,head_size) @ (B,head_size,T) -> (B,T,T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B,T,T)
        wei = F.softmax(wei, dim=-1) # (B,T,T)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,head_size)
        out = wei @ v # (B,T,T) @ (B,T,head_size) -> (B,T,head_size)
        return out
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size, n_embd, block_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(n_embd, head_size, block_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)  # (B, T, num_heads * head_size)
        out = self.proj(out)
        return out
    
class FeedFoward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd)
        )
    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        n_embd = config.n_embd 
        num_heads = config.n_head
        block_size = config.block_size
        head_size = n_embd // num_heads
        self.sa = MultiHeadAttention(num_heads, head_size, n_embd, block_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        
    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(x)
        return x

class Transformer(nn.Module):
    def __init__(self, config):
            super().__init__()
            self.block_size = config.block_size

            self.transformer = nn.ModuleDict(dict(
                wte = nn.Embedding(config.vocab_size, config.n_embd),
                wpe = nn.Embedding(config.block_size, config.n_embd),
                h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
                ln_f = nn.LayerNorm(config.n_embd),
            ))
            self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

            n_params = sum(p.numel() for p in self.transformer.parameters())
            print("number of parameters: %.2fM" % (n_params/1e6,))

    def get_block_size(self):
        return self.block_size

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.block_size, f"Cannot forward sequence of length {t}, block size is only {self.block_size}"
        pos = torch.arange(0, t, dtype=torch.long, device=device).unsqueeze(0) # shape (1, t)

        # forward the GPT model itself
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (b, t, n_embd)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (1, t, n_embd)
        x = tok_emb + pos_emb
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x)

        # if we are given some desired targets also calculate the loss
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)

        return logits, loss

# %%
# Determine device (MPS for Apple Silicon, CUDA for NVIDIA, CPU as fallback)
if torch.backends.mps.is_available():
    device = torch.device('mps')
    print("Using MPS (Metal Performance Shaders)")
elif torch.cuda.is_available():
    device = torch.device('cuda')
    print("Using CUDA")
else:
    device = torch.device('cpu')
    print("Using CPU")

transformer = Transformer(config)
transformer = transformer.to(device)
writer = SummaryWriter(log_dir='./training_dir')
if __name__ == '__main__':
    # init optimizer
    optimizer = torch.optim.AdamW(transformer.parameters(), lr=5e-4, weight_decay=0.01, betas=(0.9, 0.99), eps=1e-8)

    # init dataloader
    batch_loader = InfiniteDataLoader(train_dataset, batch_size=64, pin_memory=False, num_workers=0)

    # training loop
    best_loss = None
    step = 0
    while True:

        t0 = time.time()

        # get the next batch, ship to device, and unpack it to input and target
        batch = batch_loader.next()
        batch = [t.to(device) for t in batch]
        X, Y = batch

        # feed into the model
        logits, loss = transformer(X, Y)

        # calculate the gradient, update the weights
        transformer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        t1 = time.time()

        # logging
        if step % 10 == 0:
            print(f"step {step} | loss {loss.item():.4f} | step time {(t1-t0)*1000:.2f}ms")
        # evaluate the model
        if step > 0 and step % 500 == 0:
            train_loss = evaluate(transformer, train_dataset, device, batch_size=100, max_batches=10)
            test_loss  = evaluate(transformer, test_dataset, device, batch_size=100, max_batches=10)
            writer.add_scalar("Loss/train", train_loss, step)
            writer.add_scalar("Loss/test", test_loss, step)
            writer.flush()
            print(f"step {step} train loss: {train_loss} test loss: {test_loss}")
            # save the model to disk if it has improved
            if best_loss is None or test_loss < best_loss:
                out_path = os.path.join('./training_dir', "transformer.pt")
                print(f"test loss {test_loss} is the best so far, saving model to {out_path}")
                torch.save(transformer.state_dict(), out_path)
                best_loss = test_loss
        # sample from the model
        if step > 0 and step % 200 == 0:
            print_samples(transformer, train_dataset, device=device, num=10)
        step += 1
# Out:
# Using MPS (Metal Performance Shaders)
# number of parameters: 10.66M
# step 0 | loss 3.8030 | step time 123.10ms
# step 10 | loss 2.9027 | step time 119.19ms
# step 20 | loss 2.4808 | step time 118.70ms
# step 30 | loss 2.6420 | step time 118.17ms
# step 40 | loss 2.6384 | step time 117.74ms
# step 50 | loss 2.2506 | step time 129.20ms
# step 60 | loss 2.5379 | step time 122.11ms
# step 70 | loss 2.5961 | step time 129.16ms
# step 80 | loss 2.7412 | step time 119.41ms
# step 90 | loss 2.1155 | step time 119.80ms
# step 100 | loss 1.8900 | step time 121.86ms
# step 110 | loss 2.5255 | step time 118.10ms
# step 120 | loss 2.0532 | step time 121.66ms
# step 130 | loss 2.1888 | step time 121.65ms
# step 140 | loss 2.9278 | step time 119.66ms
# step 150 | loss 1.6883 | step time 122.70ms
# step 160 | loss 2.8465 | step time 120.21ms
# step 170 | loss 2.1643 | step time 118.95ms
# step 180 | loss 2.1699 | step time 117.80ms
# step 190 | loss 2.1306 | step time 116.95ms
# step 200 | loss 2.0626 | step time 117.39ms
# --------------------------------------------------------------------------------
# 2 samples that are in train:
# other
# the
# 0 samples that are in test:
# 8 samples that are new:
# ioderedenentedicu
# ofoninenoton
# ifsit
# pshevapatuns
# cechemension
# oruny
# tchioren
# efchr
# --------------------------------------------------------------------------------
# step 210 | loss 2.2298 | step time 121.04ms
# step 220 | loss 1.8372 | step time 125.28ms
# step 230 | loss 2.4363 | step time 117.42ms
# step 240 | loss 1.9068 | step time 117.43ms
# step 250 | loss 2.4212 | step time 123.32ms
# step 260 | loss 2.4302 | step time 123.25ms
# step 270 | loss 1.8769 | step time 123.79ms
# step 280 | loss 1.6603 | step time 115.19ms
# step 290 | loss 2.1164 | step time 119.97ms
# step 300 | loss 1.8861 | step time 120.43ms
# step 310 | loss 1.6858 | step time 123.77ms
# step 320 | loss 2.1766 | step time 123.79ms
# step 330 | loss 1.6703 | step time 123.63ms
# step 340 | loss 2.3039 | step time 128.49ms
# step 350 | loss 2.1411 | step time 123.38ms
# step 360 | loss 1.1594 | step time 117.25ms
# step 370 | loss 1.4026 | step time 116.34ms
# step 380 | loss 2.2368 | step time 119.45ms
# step 390 | loss 2.1632 | step time 117.77ms
# step 400 | loss 1.2892 | step time 117.07ms
# --------------------------------------------------------------------------------
# 4 samples that are in train:
# the
# e
# rate
# a
# 0 samples that are in test:
# 6 samples that are new:
# cnlallecent
# aupe
# cull
# rous
# consencules
# releonge
# --------------------------------------------------------------------------------
# step 410 | loss 2.0545 | step time 117.94ms
# step 420 | loss 2.7431 | step time 118.99ms
# step 430 | loss 1.3555 | step time 120.56ms
# step 440 | loss 1.6854 | step time 119.09ms
# step 450 | loss 1.9465 | step time 119.58ms
# step 460 | loss 1.9523 | step time 123.16ms
# step 470 | loss 1.2889 | step time 120.15ms
# step 480 | loss 1.5635 | step time 126.16ms
# step 490 | loss 1.4809 | step time 117.15ms
# step 500 | loss 1.2856 | step time 115.90ms
# step 500 train loss: 2.0020041465759277 test loss: 2.0192224979400635
# test loss 2.0192224979400635 is the best so far, saving model to ./training_dir/transformer.pt
# step 510 | loss 1.7891 | step time 122.76ms
# step 520 | loss 1.9042 | step time 120.74ms
# step 530 | loss 2.3064 | step time 120.00ms
# step 540 | loss 2.0789 | step time 127.97ms
# step 550 | loss 1.8545 | step time 125.58ms
# step 560 | loss 1.9616 | step time 118.97ms
# step 570 | loss 1.3705 | step time 118.27ms
# step 580 | loss 0.9761 | step time 118.32ms
# step 590 | loss 1.9222 | step time 120.96ms
# step 600 | loss 1.5156 | step time 121.07ms
# --------------------------------------------------------------------------------
# 6 samples that are in train:
# a
# b
# the
# under
# under
# party
# 0 samples that are in test:
# 4 samples that are new:
# partion
# ol
# undect
# pared
# --------------------------------------------------------------------------------
# step 610 | loss 2.2152 | step time 119.32ms
# step 620 | loss 1.4563 | step time 116.85ms
# step 630 | loss 2.2119 | step time 117.50ms
# step 640 | loss 2.0109 | step time 117.85ms
# step 650 | loss 1.5892 | step time 118.54ms
# step 660 | loss 1.9526 | step time 119.02ms
# step 670 | loss 2.6528 | step time 117.60ms
# step 680 | loss 1.8141 | step time 124.78ms
# step 690 | loss 1.4623 | step time 119.24ms
# step 700 | loss 2.6625 | step time 122.23ms
# step 710 | loss 1.8308 | step time 137.19ms
# step 720 | loss 2.2476 | step time 123.71ms
# step 730 | loss 1.4267 | step time 128.58ms
# step 740 | loss 2.1920 | step time 121.25ms
# step 750 | loss 2.0108 | step time 117.70ms
# step 760 | loss 2.1763 | step time 114.44ms
# step 770 | loss 1.7775 | step time 121.00ms
# step 780 | loss 1.9916 | step time 117.86ms
# step 790 | loss 1.5849 | step time 116.95ms
# step 800 | loss 1.8641 | step time 119.17ms
# --------------------------------------------------------------------------------
# 5 samples that are in train:
# the
# to
# n
# a
# the
# 0 samples that are in test:
# 5 samples that are new:
# tormenatins
# isstopor
# anydementated
# ationcer
# consecte
# --------------------------------------------------------------------------------
# step 810 | loss 1.3130 | step time 117.34ms
# step 820 | loss 1.7314 | step time 128.30ms
# step 830 | loss 2.6245 | step time 118.74ms
# step 840 | loss 1.9578 | step time 119.45ms
# step 850 | loss 1.7818 | step time 119.43ms
# step 860 | loss 1.7998 | step time 120.21ms
# step 870 | loss 1.4208 | step time 120.27ms
# step 880 | loss 2.1111 | step time 117.84ms
# step 890 | loss 1.5860 | step time 116.29ms
# step 900 | loss 1.7946 | step time 116.60ms
# step 910 | loss 2.2123 | step time 115.79ms
# step 920 | loss 2.0402 | step time 118.96ms
# step 930 | loss 1.3798 | step time 116.87ms
# step 940 | loss 1.0268 | step time 119.48ms
# step 950 | loss 2.0108 | step time 118.66ms
# step 960 | loss 2.1129 | step time 119.09ms
# step 970 | loss 1.4987 | step time 127.06ms
# step 980 | loss 1.5642 | step time 121.39ms
# step 990 | loss 1.3202 | step time 120.23ms
# step 1000 | loss 1.0411 | step time 120.35ms
# step 1000 train loss: 1.7030940055847168 test loss: 1.7930248975753784
# test loss 1.7930248975753784 is the best so far, saving model to ./training_dir/transformer.pt
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# and
# of
# s
# party
# so
# party
# term
# 0 samples that are in test:
# 3 samples that are new:
# try
# othor
# ce
# --------------------------------------------------------------------------------
# step 1010 | loss 1.9875 | step time 137.12ms
# step 1020 | loss 2.5683 | step time 123.84ms
# step 1030 | loss 1.2571 | step time 118.47ms
# step 1040 | loss 1.3354 | step time 121.50ms
# step 1050 | loss 1.2651 | step time 126.60ms
# step 1060 | loss 2.3815 | step time 120.97ms
# step 1070 | loss 1.4135 | step time 127.75ms
# step 1080 | loss 1.9701 | step time 125.91ms
# step 1090 | loss 1.8843 | step time 121.12ms
# step 1100 | loss 1.4306 | step time 119.14ms
# step 1110 | loss 2.3612 | step time 121.25ms
# step 1120 | loss 1.6545 | step time 118.51ms
# step 1130 | loss 1.3502 | step time 120.62ms
# step 1140 | loss 1.7124 | step time 120.31ms
# step 1150 | loss 2.0028 | step time 119.40ms
# step 1160 | loss 2.0337 | step time 118.27ms
# step 1170 | loss 1.4881 | step time 120.60ms
# step 1180 | loss 1.9239 | step time 125.33ms
# step 1190 | loss 2.6966 | step time 124.70ms
# step 1200 | loss 1.3778 | step time 125.84ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# as
# to
# the
# ow
# or
# written
# by
# 0 samples that are in test:
# 3 samples that are new:
# partcy
# wath
# purst
# --------------------------------------------------------------------------------
# step 1210 | loss 1.7685 | step time 121.55ms
# step 1220 | loss 1.2846 | step time 116.30ms
# step 1230 | loss 1.8388 | step time 118.32ms
# step 1240 | loss 1.5766 | step time 114.76ms
# step 1250 | loss 1.6205 | step time 117.01ms
# step 1260 | loss 1.6037 | step time 117.11ms
# step 1270 | loss 1.4528 | step time 115.70ms
# step 1280 | loss 1.6964 | step time 125.46ms
# step 1290 | loss 1.5829 | step time 126.27ms
# step 1300 | loss 1.0906 | step time 120.42ms
# step 1310 | loss 1.7195 | step time 118.14ms
# step 1320 | loss 1.2234 | step time 117.01ms
# step 1330 | loss 1.9438 | step time 125.26ms
# step 1340 | loss 2.0801 | step time 115.93ms
# step 1350 | loss 1.6529 | step time 123.88ms
# step 1360 | loss 1.2455 | step time 116.39ms
# step 1370 | loss 1.5567 | step time 120.01ms
# step 1380 | loss 1.7968 | step time 123.90ms
# step 1390 | loss 2.0143 | step time 115.45ms
# step 1400 | loss 1.9772 | step time 121.65ms
# --------------------------------------------------------------------------------
# 5 samples that are in train:
# and
# as
# the
# or
# with
# 0 samples that are in test:
# 5 samples that are new:
# suthored
# agrmem
# insuipolss
# iinier
# belept
# --------------------------------------------------------------------------------
# step 1410 | loss 1.5895 | step time 121.73ms
# step 1420 | loss 2.3756 | step time 118.63ms
# step 1430 | loss 2.3049 | step time 119.89ms
# step 1440 | loss 2.1384 | step time 119.27ms
# step 1450 | loss 1.4175 | step time 118.82ms
# step 1460 | loss 1.4638 | step time 117.33ms
# step 1470 | loss 2.2349 | step time 118.22ms
# step 1480 | loss 1.9247 | step time 117.02ms
# step 1490 | loss 2.6949 | step time 120.05ms
# step 1500 | loss 1.5662 | step time 113.65ms
# step 1500 train loss: 1.6131435632705688 test loss: 1.6708437204360962
# test loss 1.6708437204360962 is the best so far, saving model to ./training_dir/transformer.pt
# step 1510 | loss 2.5380 | step time 149.33ms
# step 1520 | loss 2.0797 | step time 122.95ms
# step 1530 | loss 2.0276 | step time 115.00ms
# step 1540 | loss 1.0559 | step time 120.79ms
# step 1550 | loss 1.7235 | step time 123.33ms
# step 1560 | loss 1.7925 | step time 124.67ms
# step 1570 | loss 2.1285 | step time 115.71ms
# step 1580 | loss 1.1072 | step time 118.21ms
# step 1590 | loss 1.6284 | step time 120.17ms
# step 1600 | loss 1.6906 | step time 116.53ms
# --------------------------------------------------------------------------------
# 6 samples that are in train:
# by
# trust
# under
# if
# the
# of
# 0 samples that are in test:
# 4 samples that are new:
# deliviwdencent
# bialid
# tre
# udpsualed
# --------------------------------------------------------------------------------
# step 1610 | loss 1.1201 | step time 123.88ms
# step 1620 | loss 1.3258 | step time 118.17ms
# step 1630 | loss 2.5227 | step time 115.51ms
# step 1640 | loss 2.0085 | step time 126.24ms
# step 1650 | loss 2.3104 | step time 119.43ms
# step 1660 | loss 1.6194 | step time 120.84ms
# step 1670 | loss 1.1525 | step time 124.44ms
# step 1680 | loss 1.6379 | step time 117.04ms
# step 1690 | loss 2.1471 | step time 116.44ms
# step 1700 | loss 2.1137 | step time 124.30ms
# step 1710 | loss 1.8292 | step time 117.11ms
# step 1720 | loss 1.1808 | step time 124.73ms
# step 1730 | loss 1.3061 | step time 119.35ms
# step 1740 | loss 1.9097 | step time 115.70ms
# step 1750 | loss 1.5167 | step time 117.27ms
# step 1760 | loss 1.6273 | step time 118.70ms
# step 1770 | loss 1.2579 | step time 115.41ms
# step 1780 | loss 1.5435 | step time 116.78ms
# step 1790 | loss 1.5778 | step time 114.99ms
# step 1800 | loss 1.5898 | step time 113.76ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# of
# a
# such
# of
# provide
# party
# b
# the
# 0 samples that are in test:
# 2 samples that are new:
# bencer
# othll
# --------------------------------------------------------------------------------
# step 1810 | loss 1.6240 | step time 118.11ms
# step 1820 | loss 1.6820 | step time 117.52ms
# step 1830 | loss 2.2580 | step time 117.67ms
# step 1840 | loss 1.8423 | step time 117.43ms
# step 1850 | loss 1.5532 | step time 116.69ms
# step 1860 | loss 1.6011 | step time 118.05ms
# step 1870 | loss 2.2007 | step time 118.99ms
# step 1880 | loss 1.7680 | step time 117.92ms
# step 1890 | loss 1.7135 | step time 117.68ms
# step 1900 | loss 1.8543 | step time 117.58ms
# step 1910 | loss 1.3477 | step time 116.58ms
# step 1920 | loss 0.6974 | step time 118.40ms
# step 1930 | loss 1.4655 | step time 113.76ms
# step 1940 | loss 2.2132 | step time 118.79ms
# step 1950 | loss 1.4456 | step time 117.97ms
# step 1960 | loss 1.3517 | step time 118.09ms
# step 1970 | loss 2.2365 | step time 115.11ms
# step 1980 | loss 0.8291 | step time 119.47ms
# step 1990 | loss 2.2239 | step time 113.72ms
# step 2000 | loss 1.7395 | step time 119.73ms
# step 2000 train loss: 1.5881489515304565 test loss: 1.6421102285385132
# test loss 1.6421102285385132 is the best so far, saving model to ./training_dir/transformer.pt
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# or
# date
# to
# party
# the
# a
# and
# of
# 0 samples that are in test:
# 2 samples that are new:
# transacted
# dort
# --------------------------------------------------------------------------------
# step 2010 | loss 2.4404 | step time 117.63ms
# step 2020 | loss 1.9045 | step time 114.49ms
# step 2030 | loss 1.8008 | step time 120.07ms
# step 2040 | loss 1.5175 | step time 117.00ms
# step 2050 | loss 2.0471 | step time 116.80ms
# step 2060 | loss 1.1349 | step time 115.93ms
# step 2070 | loss 1.1942 | step time 115.45ms
# step 2080 | loss 1.8316 | step time 111.24ms
# step 2090 | loss 2.2762 | step time 115.92ms
# step 2100 | loss 1.3808 | step time 118.66ms
# step 2110 | loss 1.4176 | step time 116.16ms
# step 2120 | loss 1.5782 | step time 117.94ms
# step 2130 | loss 1.8736 | step time 118.32ms
# step 2140 | loss 1.3868 | step time 118.64ms
# step 2150 | loss 2.1402 | step time 118.95ms
# step 2160 | loss 1.8884 | step time 117.63ms
# step 2170 | loss 2.1165 | step time 115.55ms
# step 2180 | loss 1.4053 | step time 115.32ms
# step 2190 | loss 1.5608 | step time 118.41ms
# step 2200 | loss 1.6021 | step time 114.63ms
# --------------------------------------------------------------------------------
# 6 samples that are in train:
# party
# p
# which
# term
# b
# term
# 0 samples that are in test:
# 4 samples that are new:
# termifises
# wall
# suppsennieentos
# secer
# --------------------------------------------------------------------------------
# step 2210 | loss 1.1125 | step time 116.37ms
# step 2220 | loss 2.0401 | step time 117.99ms
# step 2230 | loss 1.7480 | step time 117.17ms
# step 2240 | loss 1.9600 | step time 115.57ms
# step 2250 | loss 1.3198 | step time 116.73ms
# step 2260 | loss 1.9840 | step time 119.14ms
# step 2270 | loss 0.9936 | step time 117.55ms
# step 2280 | loss 2.1045 | step time 115.50ms
# step 2290 | loss 1.3434 | step time 117.47ms
# step 2300 | loss 2.0604 | step time 114.95ms
# step 2310 | loss 0.9511 | step time 116.11ms
# step 2320 | loss 1.2772 | step time 116.76ms
# step 2330 | loss 1.7380 | step time 117.98ms
# step 2340 | loss 2.0046 | step time 110.11ms
# step 2350 | loss 1.3699 | step time 116.42ms
# step 2360 | loss 2.0889 | step time 116.66ms
# step 2370 | loss 1.9230 | step time 113.47ms
# step 2380 | loss 1.4524 | step time 114.73ms
# step 2390 | loss 1.4262 | step time 118.05ms
# step 2400 | loss 2.1956 | step time 118.91ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# of
# the
# or
# and
# is
# it
# the
# 0 samples that are in test:
# 3 samples that are new:
# prans
# privonadedemmenti
# possibleent
# --------------------------------------------------------------------------------
# step 2410 | loss 1.9802 | step time 117.62ms
# step 2420 | loss 0.9701 | step time 114.81ms
# step 2430 | loss 0.9458 | step time 118.25ms
# step 2440 | loss 1.0980 | step time 115.50ms
# step 2450 | loss 1.9420 | step time 117.26ms
# step 2460 | loss 2.0813 | step time 119.38ms
# step 2470 | loss 0.9615 | step time 115.34ms
# step 2480 | loss 1.3644 | step time 116.60ms
# step 2490 | loss 1.6247 | step time 114.52ms
# step 2500 | loss 1.5153 | step time 116.74ms
# step 2500 train loss: 1.5875331163406372 test loss: 1.6526844501495361
# step 2510 | loss 1.4937 | step time 117.21ms
# step 2520 | loss 1.6947 | step time 118.06ms
# step 2530 | loss 0.9640 | step time 119.78ms
# step 2540 | loss 1.4522 | step time 118.31ms
# step 2550 | loss 1.0264 | step time 116.20ms
# step 2560 | loss 1.9070 | step time 117.25ms
# step 2570 | loss 1.2913 | step time 120.18ms
# step 2580 | loss 1.7833 | step time 119.25ms
# step 2590 | loss 1.2199 | step time 117.12ms
# step 2600 | loss 1.6649 | step time 119.86ms
# --------------------------------------------------------------------------------
# 10 samples that are in train:
# b
# this
# b
# of
# by
# this
# by
# the
# other
# of
# 0 samples that are in test:
# 0 samples that are new:
# --------------------------------------------------------------------------------
# step 2610 | loss 1.6572 | step time 121.98ms
# step 2620 | loss 1.5009 | step time 120.55ms
# step 2630 | loss 1.0435 | step time 117.86ms
# step 2640 | loss 1.0822 | step time 116.95ms
# step 2650 | loss 2.3887 | step time 118.67ms
# step 2660 | loss 1.6886 | step time 118.61ms
# step 2670 | loss 2.7314 | step time 117.74ms
# step 2680 | loss 1.6519 | step time 117.20ms
# step 2690 | loss 1.3978 | step time 115.93ms
# step 2700 | loss 2.2168 | step time 116.72ms
# step 2710 | loss 1.4480 | step time 115.68ms
# step 2720 | loss 1.7759 | step time 117.58ms
# step 2730 | loss 0.9641 | step time 116.81ms
# step 2740 | loss 1.8240 | step time 114.45ms
# step 2750 | loss 2.3033 | step time 118.04ms
# step 2760 | loss 1.5178 | step time 114.16ms
# step 2770 | loss 0.9522 | step time 118.60ms
# step 2780 | loss 1.0418 | step time 117.28ms
# step 2790 | loss 2.4003 | step time 115.39ms
# step 2800 | loss 1.2500 | step time 118.35ms
# --------------------------------------------------------------------------------
# 4 samples that are in train:
# such
# default
# section
# it
# 0 samples that are in test:
# 6 samples that are new:
# ceuntits
# actingat
# alllw
# tetingrent
# poute
# consr
# --------------------------------------------------------------------------------
# step 2810 | loss 2.1630 | step time 118.25ms
# step 2820 | loss 2.4866 | step time 116.55ms
# step 2830 | loss 1.4199 | step time 120.32ms
# step 2840 | loss 1.1709 | step time 116.99ms
# step 2850 | loss 1.5791 | step time 115.78ms
# step 2860 | loss 1.3442 | step time 115.42ms
# step 2870 | loss 1.3244 | step time 118.52ms
# step 2880 | loss 0.7241 | step time 116.29ms
# step 2890 | loss 1.9704 | step time 119.44ms
# step 2900 | loss 1.8710 | step time 117.66ms
# step 2910 | loss 1.5302 | step time 114.92ms
# step 2920 | loss 1.3055 | step time 116.14ms
# step 2930 | loss 2.1274 | step time 116.53ms
# step 2940 | loss 1.4914 | step time 117.30ms
# step 2950 | loss 1.3881 | step time 115.26ms
# step 2960 | loss 1.3639 | step time 115.37ms
# step 2970 | loss 1.3416 | step time 117.96ms
# step 2980 | loss 0.5994 | step time 116.75ms
# step 2990 | loss 2.0684 | step time 116.33ms
# step 3000 | loss 1.5294 | step time 118.62ms
# step 3000 train loss: 1.5095351934432983 test loss: 1.6088842153549194
# test loss 1.6088842153549194 is the best so far, saving model to ./training_dir/transformer.pt
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# the
# will
# ii
# party
# any
# and
# other
# 0 samples that are in test:
# 3 samples that are new:
# ia
# transase
# teplanacip
# --------------------------------------------------------------------------------
# step 3010 | loss 1.2687 | step time 117.81ms
# step 3020 | loss 1.2577 | step time 119.04ms
# step 3030 | loss 1.4740 | step time 115.97ms
# step 3040 | loss 2.2073 | step time 118.26ms
# step 3050 | loss 1.1721 | step time 115.57ms
# step 3060 | loss 1.6514 | step time 117.78ms
# step 3070 | loss 1.4439 | step time 116.51ms
# step 3080 | loss 1.0574 | step time 114.55ms
# step 3090 | loss 1.8224 | step time 116.92ms
# step 3100 | loss 1.6437 | step time 112.22ms
# step 3110 | loss 1.3057 | step time 115.78ms
# step 3120 | loss 1.6462 | step time 117.41ms
# step 3130 | loss 1.9006 | step time 117.39ms
# step 3140 | loss 1.9104 | step time 117.05ms
# step 3150 | loss 1.0178 | step time 115.62ms
# step 3160 | loss 1.6968 | step time 119.54ms
# step 3170 | loss 1.3392 | step time 117.69ms
# step 3180 | loss 1.2966 | step time 116.23ms
# step 3190 | loss 1.0452 | step time 114.28ms
# step 3200 | loss 1.3495 | step time 116.41ms
# --------------------------------------------------------------------------------
# 6 samples that are in train:
# i
# a
# or
# shall
# and
# to
# 0 samples that are in test:
# 4 samples that are new:
# delivere
# senim
# thit
# there
# --------------------------------------------------------------------------------
# step 3210 | loss 1.7436 | step time 116.34ms
# step 3220 | loss 1.9685 | step time 117.95ms
# step 3230 | loss 1.5791 | step time 114.44ms
# step 3240 | loss 2.5570 | step time 117.24ms
# step 3250 | loss 1.4510 | step time 116.89ms
# step 3260 | loss 1.4257 | step time 115.34ms
# step 3270 | loss 1.7587 | step time 118.22ms
# step 3280 | loss 1.8695 | step time 116.35ms
# step 3290 | loss 0.9999 | step time 119.17ms
# step 3300 | loss 1.1240 | step time 118.09ms
# step 3310 | loss 1.8164 | step time 117.79ms
# step 3320 | loss 1.1816 | step time 117.43ms
# step 3330 | loss 0.8376 | step time 114.85ms
# step 3340 | loss 1.2537 | step time 117.75ms
# step 3350 | loss 1.7117 | step time 115.30ms
# step 3360 | loss 1.6088 | step time 116.95ms
# step 3370 | loss 1.4663 | step time 115.71ms
# step 3380 | loss 1.9913 | step time 118.69ms
# step 3390 | loss 1.5761 | step time 115.37ms
# step 3400 | loss 1.6595 | step time 117.73ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# this
# the
# event
# each
# to
# and
# section
# 0 samples that are in test:
# 3 samples that are new:
# pthess
# resuctint
# dectsts
# --------------------------------------------------------------------------------
# step 3410 | loss 1.8241 | step time 112.39ms
# step 3420 | loss 1.4862 | step time 117.46ms
# step 3430 | loss 1.7585 | step time 114.19ms
# step 3440 | loss 0.8830 | step time 118.36ms
# step 3450 | loss 0.9122 | step time 118.36ms
# step 3460 | loss 1.6570 | step time 118.80ms
# step 3470 | loss 0.8836 | step time 114.05ms
# step 3480 | loss 2.4323 | step time 120.08ms
# step 3490 | loss 1.8218 | step time 117.65ms
# step 3500 | loss 1.0473 | step time 117.91ms
# step 3500 train loss: 1.4378329515457153 test loss: 1.584360122680664
# test loss 1.584360122680664 is the best so far, saving model to ./training_dir/transformer.pt
# step 3510 | loss 1.3383 | step time 120.27ms
# step 3520 | loss 1.0610 | step time 119.00ms
# step 3530 | loss 1.4893 | step time 117.29ms
# step 3540 | loss 0.9357 | step time 116.52ms
# step 3550 | loss 1.5712 | step time 118.41ms
# step 3560 | loss 1.0766 | step time 118.83ms
# step 3570 | loss 1.6392 | step time 117.99ms
# step 3580 | loss 2.2152 | step time 116.94ms
# step 3590 | loss 1.6554 | step time 119.34ms
# step 3600 | loss 1.9214 | step time 118.36ms
# --------------------------------------------------------------------------------
# 5 samples that are in train:
# this
# to
# this
# such
# and
# 0 samples that are in test:
# 5 samples that are new:
# wrhold
# sinen
# soniony
# betres
# issuac
# --------------------------------------------------------------------------------
# step 3610 | loss 1.2479 | step time 115.27ms
# step 3620 | loss 1.6770 | step time 119.23ms
# step 3630 | loss 0.8177 | step time 116.80ms
# step 3640 | loss 1.6556 | step time 118.18ms
# step 3650 | loss 1.4845 | step time 116.82ms
# step 3660 | loss 1.7788 | step time 112.93ms
# step 3670 | loss 1.4601 | step time 116.69ms
# step 3680 | loss 1.5767 | step time 117.40ms
# step 3690 | loss 1.1581 | step time 118.82ms
# step 3700 | loss 1.6207 | step time 115.53ms
# step 3710 | loss 1.6253 | step time 116.00ms
# step 3720 | loss 1.1213 | step time 112.40ms
# step 3730 | loss 1.7429 | step time 118.22ms
# step 3740 | loss 0.9467 | step time 116.27ms
# step 3750 | loss 1.5990 | step time 116.13ms
# step 3760 | loss 1.6208 | step time 115.07ms
# step 3770 | loss 1.8484 | step time 117.51ms
# step 3780 | loss 1.2346 | step time 117.86ms
# step 3790 | loss 2.0254 | step time 116.66ms
# step 3800 | loss 1.5764 | step time 117.36ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# any
# of
# or
# the
# are
# the
# a
# 0 samples that are in test:
# 3 samples that are new:
# thon
# dellt
# opplsse
# --------------------------------------------------------------------------------
# step 3810 | loss 1.0230 | step time 118.04ms
# step 3820 | loss 1.5440 | step time 116.99ms
# step 3830 | loss 1.1917 | step time 117.47ms
# step 3840 | loss 2.5862 | step time 118.45ms
# step 3850 | loss 2.1339 | step time 119.14ms
# step 3860 | loss 1.3490 | step time 117.17ms
# step 3870 | loss 1.2963 | step time 114.88ms
# step 3880 | loss 1.7540 | step time 117.24ms
# step 3890 | loss 1.5212 | step time 115.56ms
# step 3900 | loss 0.9131 | step time 114.16ms
# step 3910 | loss 0.9852 | step time 117.18ms
# step 3920 | loss 1.4384 | step time 119.77ms
# step 3930 | loss 1.8596 | step time 119.19ms
# step 3940 | loss 1.7495 | step time 117.09ms
# step 3950 | loss 0.9342 | step time 117.70ms
# step 3960 | loss 1.0468 | step time 116.33ms
# step 3970 | loss 1.2224 | step time 120.16ms
# step 3980 | loss 1.7772 | step time 117.06ms
# step 3990 | loss 2.0425 | step time 118.22ms
# step 4000 | loss 1.5152 | step time 116.38ms
# step 4000 train loss: 1.4593825340270996 test loss: 1.5665514469146729
# test loss 1.5665514469146729 is the best so far, saving model to ./training_dir/transformer.pt
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# to
# party
# this
# the
# on
# to
# on
# 0 samples that are in test:
# 3 samples that are new:
# entery
# beb
# partieie
# --------------------------------------------------------------------------------
# step 4010 | loss 1.3342 | step time 120.10ms
# step 4020 | loss 0.9454 | step time 117.84ms
# step 4030 | loss 1.1300 | step time 117.60ms
# step 4040 | loss 1.5810 | step time 116.32ms
# step 4050 | loss 1.3022 | step time 115.69ms
# step 4060 | loss 1.5654 | step time 118.69ms
# step 4070 | loss 1.4161 | step time 115.26ms
# step 4080 | loss 1.9648 | step time 117.25ms
# step 4090 | loss 1.0748 | step time 118.95ms
# step 4100 | loss 1.8938 | step time 118.02ms
# step 4110 | loss 1.5960 | step time 116.72ms
# step 4120 | loss 1.1137 | step time 115.63ms
# step 4130 | loss 1.6233 | step time 117.70ms
# step 4140 | loss 1.7545 | step time 118.29ms
# step 4150 | loss 1.3823 | step time 118.87ms
# step 4160 | loss 2.3567 | step time 115.85ms
# step 4170 | loss 0.9849 | step time 117.05ms
# step 4180 | loss 1.0827 | step time 115.86ms
# step 4190 | loss 1.7392 | step time 116.07ms
# step 4200 | loss 1.3986 | step time 118.20ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# trust
# party
# to
# trust
# party
# the
# the
# of
# 0 samples that are in test:
# 2 samples that are new:
# terauaare
# datey
# --------------------------------------------------------------------------------
# step 4210 | loss 1.1248 | step time 116.99ms
# step 4220 | loss 0.9601 | step time 115.05ms
# step 4230 | loss 1.7045 | step time 116.97ms
# step 4240 | loss 1.4333 | step time 114.07ms
# step 4250 | loss 1.2259 | step time 116.51ms
# step 4260 | loss 1.0309 | step time 116.89ms
# step 4270 | loss 1.0716 | step time 115.52ms
# step 4280 | loss 1.6908 | step time 119.17ms
# step 4290 | loss 1.2995 | step time 116.56ms
# step 4300 | loss 1.8810 | step time 115.68ms
# step 4310 | loss 1.7480 | step time 117.23ms
# step 4320 | loss 2.3079 | step time 119.99ms
# step 4330 | loss 1.9938 | step time 118.25ms
# step 4340 | loss 1.6306 | step time 117.41ms
# step 4350 | loss 1.7493 | step time 119.74ms
# step 4360 | loss 1.7123 | step time 114.31ms
# step 4370 | loss 1.1018 | step time 119.41ms
# step 4380 | loss 1.7982 | step time 114.27ms
# step 4390 | loss 1.1352 | step time 117.11ms
# step 4400 | loss 0.6682 | step time 112.09ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# of
# the
# days
# from
# of
# and
# the
# 0 samples that are in test:
# 3 samples that are new:
# docummanryangry
# agreemencedit
# agreemenc
# --------------------------------------------------------------------------------
# step 4410 | loss 1.8481 | step time 115.07ms
# step 4420 | loss 1.5286 | step time 116.33ms
# step 4430 | loss 1.1081 | step time 116.35ms
# step 4440 | loss 1.0173 | step time 116.86ms
# step 4450 | loss 2.4971 | step time 115.57ms
# step 4460 | loss 1.5147 | step time 118.80ms
# step 4470 | loss 1.4521 | step time 116.71ms
# step 4480 | loss 1.3414 | step time 119.07ms
# step 4490 | loss 1.0416 | step time 116.36ms
# step 4500 | loss 1.2584 | step time 115.69ms
# step 4500 train loss: 1.496087670326233 test loss: 1.540421724319458
# test loss 1.540421724319458 is the best so far, saving model to ./training_dir/transformer.pt
# step 4510 | loss 1.1698 | step time 122.32ms
# step 4520 | loss 1.4502 | step time 116.50ms
# step 4530 | loss 0.9645 | step time 118.69ms
# step 4540 | loss 1.0294 | step time 112.75ms
# step 4550 | loss 1.6231 | step time 116.35ms
# step 4560 | loss 1.4938 | step time 115.91ms
# step 4570 | loss 1.7439 | step time 119.86ms
# step 4580 | loss 1.6624 | step time 116.98ms
# step 4590 | loss 1.1973 | step time 115.64ms
# step 4600 | loss 1.1787 | step time 114.55ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# or
# with
# party
# of
# any
# appoints
# and
# 0 samples that are in test:
# 3 samples that are new:
# anterwtifaengs
# parts
# collater
# --------------------------------------------------------------------------------
# step 4610 | loss 1.9073 | step time 116.44ms
# step 4620 | loss 0.6960 | step time 115.72ms
# step 4630 | loss 1.1890 | step time 118.24ms
# step 4640 | loss 1.7931 | step time 116.86ms
# step 4650 | loss 1.2155 | step time 115.17ms
# step 4660 | loss 1.7031 | step time 117.44ms
# step 4670 | loss 1.9514 | step time 116.84ms
# step 4680 | loss 0.8952 | step time 113.50ms
# step 4690 | loss 1.5780 | step time 114.78ms
# step 4700 | loss 1.6366 | step time 117.24ms
# step 4710 | loss 1.9974 | step time 116.75ms
# step 4720 | loss 1.4126 | step time 115.91ms
# step 4730 | loss 1.3415 | step time 114.83ms
# step 4740 | loss 1.4991 | step time 115.26ms
# step 4750 | loss 0.8752 | step time 115.46ms
# step 4760 | loss 1.1990 | step time 117.54ms
# step 4770 | loss 1.0599 | step time 116.42ms
# step 4780 | loss 1.6270 | step time 116.02ms
# step 4790 | loss 1.7126 | step time 117.08ms
# step 4800 | loss 1.0401 | step time 116.98ms
# --------------------------------------------------------------------------------
# 9 samples that are in train:
# to
# at
# that
# the
# se
# such
# of
# by
# inc
# 0 samples that are in test:
# 1 samples that are new:
# ineotant
# --------------------------------------------------------------------------------
# step 4810 | loss 1.1892 | step time 119.09ms
# step 4820 | loss 2.0204 | step time 118.58ms
# step 4830 | loss 1.3600 | step time 113.01ms
# step 4840 | loss 1.7824 | step time 118.74ms
# step 4850 | loss 1.8129 | step time 116.03ms
# step 4860 | loss 1.3585 | step time 117.87ms
# step 4870 | loss 2.1347 | step time 117.66ms
# step 4880 | loss 1.5716 | step time 117.08ms
# step 4890 | loss 1.7125 | step time 117.26ms
# step 4900 | loss 1.1804 | step time 118.26ms
# step 4910 | loss 1.2558 | step time 116.09ms
# step 4920 | loss 1.0538 | step time 120.11ms
# step 4930 | loss 1.1223 | step time 119.99ms
# step 4940 | loss 1.0325 | step time 115.95ms
# step 4950 | loss 0.8787 | step time 119.33ms
# step 4960 | loss 1.1420 | step time 117.28ms
# step 4970 | loss 1.0798 | step time 115.91ms
# step 4980 | loss 1.0621 | step time 115.82ms
# step 4990 | loss 1.4319 | step time 116.55ms
# step 5000 | loss 1.5655 | step time 120.24ms
# step 5000 train loss: 1.4790446758270264 test loss: 1.5078250169754028
# test loss 1.5078250169754028 is the best so far, saving model to ./training_dir/transformer.pt
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# of
# action
# a
# and
# of
# on
# the
# 0 samples that are in test:
# 3 samples that are new:
# certert
# requerent
# inceaury
# --------------------------------------------------------------------------------
# step 5010 | loss 1.3814 | step time 119.09ms
# step 5020 | loss 1.0833 | step time 120.24ms
# step 5030 | loss 1.7953 | step time 116.70ms
# step 5040 | loss 0.9958 | step time 118.43ms
# step 5050 | loss 1.4741 | step time 114.29ms
# step 5060 | loss 1.3794 | step time 114.30ms
# step 5070 | loss 1.5406 | step time 116.36ms
# step 5080 | loss 1.6886 | step time 118.92ms
# step 5090 | loss 1.2931 | step time 117.93ms
# step 5100 | loss 1.3067 | step time 119.59ms
# step 5110 | loss 1.1320 | step time 117.65ms
# step 5120 | loss 1.5366 | step time 116.16ms
# step 5130 | loss 1.4296 | step time 118.29ms
# step 5140 | loss 1.6159 | step time 116.92ms
# step 5150 | loss 1.1782 | step time 116.98ms
# step 5160 | loss 1.5097 | step time 115.65ms
# step 5170 | loss 1.3234 | step time 117.28ms
# step 5180 | loss 1.7944 | step time 116.25ms
# step 5190 | loss 1.7976 | step time 115.93ms
# step 5200 | loss 1.5273 | step time 113.53ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# or
# on
# agreements
# trust
# occur
# b
# of
# or
# 0 samples that are in test:
# 2 samples that are new:
# crond
# int
# --------------------------------------------------------------------------------
# step 5210 | loss 1.9735 | step time 114.72ms
# step 5220 | loss 1.2487 | step time 117.22ms
# step 5230 | loss 1.2862 | step time 119.64ms
# step 5240 | loss 1.1979 | step time 115.63ms
# step 5250 | loss 1.6258 | step time 116.46ms
# step 5260 | loss 1.1641 | step time 113.88ms
# step 5270 | loss 1.5023 | step time 115.01ms
# step 5280 | loss 1.0855 | step time 119.41ms
# step 5290 | loss 1.1671 | step time 117.19ms
# step 5300 | loss 1.4971 | step time 115.54ms
# step 5310 | loss 0.9129 | step time 115.16ms
# step 5320 | loss 1.5637 | step time 117.21ms
# step 5330 | loss 1.0710 | step time 115.27ms
# step 5340 | loss 0.8337 | step time 116.41ms
# step 5350 | loss 1.1654 | step time 116.83ms
# step 5360 | loss 1.6425 | step time 115.86ms
# step 5370 | loss 1.0692 | step time 115.93ms
# step 5380 | loss 1.2562 | step time 115.68ms
# step 5390 | loss 2.0555 | step time 118.43ms
# step 5400 | loss 1.1604 | step time 116.71ms
# --------------------------------------------------------------------------------
# 9 samples that are in train:
# s
# to
# shall
# f
# by
# such
# for
# is
# on
# 0 samples that are in test:
# 1 samples that are new:
# ann
# --------------------------------------------------------------------------------
# step 5410 | loss 2.0783 | step time 115.67ms
# step 5420 | loss 1.1507 | step time 117.76ms
# step 5430 | loss 1.9066 | step time 118.00ms
# step 5440 | loss 1.3566 | step time 122.79ms
# step 5450 | loss 0.9339 | step time 116.93ms
# step 5460 | loss 1.4859 | step time 118.75ms
# step 5470 | loss 1.1687 | step time 116.30ms
# step 5480 | loss 2.1667 | step time 117.05ms
# step 5490 | loss 1.4788 | step time 119.75ms
# step 5500 | loss 1.1015 | step time 177.07ms
# step 5500 train loss: 1.4706318378448486 test loss: 1.5421725511550903
# step 5510 | loss 1.2506 | step time 119.47ms
# step 5520 | loss 1.3629 | step time 117.45ms
# step 5530 | loss 1.3836 | step time 117.90ms
# step 5540 | loss 1.3851 | step time 116.45ms
# step 5550 | loss 2.1243 | step time 120.71ms
# step 5560 | loss 0.8386 | step time 117.85ms
# step 5570 | loss 1.2185 | step time 116.71ms
# step 5580 | loss 1.6627 | step time 118.41ms
# step 5590 | loss 1.3567 | step time 115.91ms
# step 5600 | loss 2.2327 | step time 117.88ms
# --------------------------------------------------------------------------------
# 4 samples that are in train:
# ii
# event
# a
# if
# 0 samples that are in test:
# 6 samples that are new:
# fatc
# ob
# bor
# thi
# agreementlings
# adving
# --------------------------------------------------------------------------------
# step 5610 | loss 1.5523 | step time 117.15ms
# step 5620 | loss 1.7849 | step time 119.86ms
# step 5630 | loss 1.0828 | step time 117.78ms
# step 5640 | loss 1.8112 | step time 116.44ms
# step 5650 | loss 1.9440 | step time 116.04ms
# step 5660 | loss 1.3421 | step time 117.15ms
# step 5670 | loss 0.9981 | step time 113.18ms
# step 5680 | loss 1.2808 | step time 118.13ms
# step 5690 | loss 1.1317 | step time 114.82ms
# step 5700 | loss 1.1329 | step time 114.80ms
# step 5710 | loss 1.3041 | step time 118.45ms
# step 5720 | loss 1.3978 | step time 113.81ms
# step 5730 | loss 1.1850 | step time 115.97ms
# step 5740 | loss 1.2448 | step time 114.61ms
# step 5750 | loss 0.8812 | step time 118.07ms
# step 5760 | loss 1.4563 | step time 115.53ms
# step 5770 | loss 1.6386 | step time 117.65ms
# step 5780 | loss 1.0484 | step time 115.18ms
# step 5790 | loss 1.5136 | step time 118.35ms
# step 5800 | loss 1.3069 | step time 121.08ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# this
# in
# the
# the
# to
# the
# of
# 0 samples that are in test:
# 3 samples that are new:
# deciol
# defit
# asturmededi
# --------------------------------------------------------------------------------
# step 5810 | loss 0.9223 | step time 119.26ms
# step 5820 | loss 1.0615 | step time 117.64ms
# step 5830 | loss 1.5408 | step time 113.73ms
# step 5840 | loss 0.8260 | step time 115.58ms
# step 5850 | loss 2.6070 | step time 117.56ms
# step 5860 | loss 1.5351 | step time 118.32ms
# step 5870 | loss 1.0854 | step time 117.20ms
# step 5880 | loss 0.9467 | step time 115.53ms
# step 5890 | loss 1.2919 | step time 113.31ms
# step 5900 | loss 0.9384 | step time 118.56ms
# step 5910 | loss 1.4436 | step time 118.20ms
# step 5920 | loss 1.8491 | step time 114.31ms
# step 5930 | loss 1.1004 | step time 117.66ms
# step 5940 | loss 1.6730 | step time 115.79ms
# step 5950 | loss 1.4773 | step time 118.98ms
# step 5960 | loss 1.9278 | step time 117.12ms
# step 5970 | loss 1.1199 | step time 119.02ms
# step 5980 | loss 1.2023 | step time 116.44ms
# step 5990 | loss 1.7478 | step time 116.63ms
# step 6000 | loss 1.8052 | step time 118.21ms
# step 6000 train loss: 1.4003816843032837 test loss: 1.524485468864441
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# be
# shall
# this
# of
# i
# any
# in
# of
# 0 samples that are in test:
# 2 samples that are new:
# dection
# dingity
# --------------------------------------------------------------------------------
# step 6010 | loss 1.1774 | step time 115.31ms
# step 6020 | loss 1.0996 | step time 116.72ms
# step 6030 | loss 1.6497 | step time 116.50ms
# step 6040 | loss 1.9962 | step time 116.38ms
# step 6050 | loss 2.4465 | step time 119.28ms
# step 6060 | loss 1.0548 | step time 117.62ms
# step 6070 | loss 1.8239 | step time 115.37ms
# step 6080 | loss 2.2074 | step time 114.41ms
# step 6090 | loss 2.1262 | step time 116.71ms
# step 6100 | loss 1.3584 | step time 117.96ms
# step 6110 | loss 1.2604 | step time 118.71ms
# step 6120 | loss 1.2324 | step time 117.93ms
# step 6130 | loss 1.1868 | step time 115.09ms
# step 6140 | loss 0.7971 | step time 117.60ms
# step 6150 | loss 1.2496 | step time 115.60ms
# step 6160 | loss 1.3908 | step time 117.67ms
# step 6170 | loss 3.2760 | step time 116.47ms
# step 6180 | loss 1.8274 | step time 115.77ms
# step 6190 | loss 1.1470 | step time 113.68ms
# step 6200 | loss 1.1413 | step time 121.28ms
# --------------------------------------------------------------------------------
# 5 samples that are in train:
# is
# to
# thirty
# event
# event
# 0 samples that are in test:
# 5 samples that are new:
# trualfere
# incoudts
# trur
# resuuche
# surlection
# --------------------------------------------------------------------------------
# step 6210 | loss 1.7643 | step time 116.38ms
# step 6220 | loss 1.9554 | step time 118.91ms
# step 6230 | loss 1.2308 | step time 118.57ms
# step 6240 | loss 1.7054 | step time 115.70ms
# step 6250 | loss 1.8411 | step time 117.61ms
# step 6260 | loss 1.2364 | step time 116.46ms
# step 6270 | loss 1.2303 | step time 116.36ms
# step 6280 | loss 2.1199 | step time 116.22ms
# step 6290 | loss 1.5988 | step time 118.17ms
# step 6300 | loss 1.8952 | step time 116.49ms
# step 6310 | loss 1.7781 | step time 113.13ms
# step 6320 | loss 0.8802 | step time 118.05ms
# step 6330 | loss 0.8033 | step time 118.46ms
# step 6340 | loss 1.7783 | step time 114.84ms
# step 6350 | loss 1.3633 | step time 118.52ms
# step 6360 | loss 1.2820 | step time 114.05ms
# step 6370 | loss 0.8243 | step time 115.63ms
# step 6380 | loss 1.4699 | step time 115.90ms
# step 6390 | loss 1.6387 | step time 116.40ms
# step 6400 | loss 1.7579 | step time 116.40ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# s
# and
# party
# and
# party
# of
# of
# 0 samples that are in test:
# 3 samples that are new:
# condy
# sectect
# addaition
# --------------------------------------------------------------------------------
# step 6410 | loss 1.4435 | step time 113.50ms
# step 6420 | loss 1.0688 | step time 117.53ms
# step 6430 | loss 1.1253 | step time 114.93ms
# step 6440 | loss 1.2673 | step time 111.64ms
# step 6450 | loss 1.0992 | step time 118.08ms
# step 6460 | loss 1.4858 | step time 117.41ms
# step 6470 | loss 1.2268 | step time 115.62ms
# step 6480 | loss 1.4249 | step time 116.87ms
# step 6490 | loss 1.8769 | step time 115.87ms
# step 6500 | loss 1.2389 | step time 114.97ms
# step 6500 train loss: 1.4467755556106567 test loss: 1.5098658800125122
# step 6510 | loss 1.3837 | step time 121.81ms
# step 6520 | loss 1.4472 | step time 118.38ms
# step 6530 | loss 1.4343 | step time 116.72ms
# step 6540 | loss 1.6938 | step time 116.25ms
# step 6550 | loss 1.9055 | step time 115.31ms
# step 6560 | loss 1.4773 | step time 117.89ms
# step 6570 | loss 1.1420 | step time 117.88ms
# step 6580 | loss 1.5813 | step time 117.02ms
# step 6590 | loss 1.0897 | step time 118.46ms
# step 6600 | loss 1.5900 | step time 118.43ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# o
# in
# the
# of
# party
# section
# b
# or
# 0 samples that are in test:
# 2 samples that are new:
# bhot
# evedit
# --------------------------------------------------------------------------------
# step 6610 | loss 1.3675 | step time 117.25ms
# step 6620 | loss 1.6715 | step time 116.07ms
# step 6630 | loss 1.2775 | step time 117.60ms
# step 6640 | loss 0.9539 | step time 116.96ms
# step 6650 | loss 1.7083 | step time 117.01ms
# step 6660 | loss 2.4005 | step time 118.80ms
# step 6670 | loss 1.6287 | step time 117.39ms
# step 6680 | loss 0.8783 | step time 116.55ms
# step 6690 | loss 1.2156 | step time 118.73ms
# step 6700 | loss 1.4423 | step time 117.06ms
# step 6710 | loss 1.1573 | step time 115.27ms
# step 6720 | loss 1.9453 | step time 118.12ms
# step 6730 | loss 2.6025 | step time 118.09ms
# step 6740 | loss 1.6339 | step time 116.75ms
# step 6750 | loss 1.7880 | step time 117.34ms
# step 6760 | loss 1.1257 | step time 118.03ms
# step 6770 | loss 1.2939 | step time 116.68ms
# step 6780 | loss 0.9850 | step time 119.28ms
# step 6790 | loss 1.0949 | step time 119.78ms
# step 6800 | loss 1.5444 | step time 116.17ms
# --------------------------------------------------------------------------------
# 10 samples that are in train:
# party
# this
# party
# of
# watch
# as
# such
# to
# party
# and
# 0 samples that are in test:
# 0 samples that are new:
# --------------------------------------------------------------------------------
# step 6810 | loss 2.0009 | step time 116.85ms
# step 6820 | loss 1.2096 | step time 118.68ms
# step 6830 | loss 1.1310 | step time 118.54ms
# step 6840 | loss 0.8301 | step time 118.39ms
# step 6850 | loss 0.9460 | step time 116.54ms
# step 6860 | loss 0.9070 | step time 115.81ms
# step 6870 | loss 1.5536 | step time 118.11ms
# step 6880 | loss 1.1881 | step time 117.06ms
# step 6890 | loss 0.9259 | step time 118.82ms
# step 6900 | loss 0.8854 | step time 118.27ms
# step 6910 | loss 0.9817 | step time 119.66ms
# step 6920 | loss 1.8290 | step time 117.42ms
# step 6930 | loss 2.8755 | step time 116.33ms
# step 6940 | loss 1.4348 | step time 116.01ms
# step 6950 | loss 1.6934 | step time 116.27ms
# step 6960 | loss 1.7239 | step time 116.47ms
# step 6970 | loss 1.3800 | step time 118.90ms
# step 6980 | loss 1.8239 | step time 118.63ms
# step 6990 | loss 1.5094 | step time 118.08ms
# step 7000 | loss 1.4217 | step time 117.93ms
# step 7000 train loss: 1.4239599704742432 test loss: 1.490254282951355
# test loss 1.490254282951355 is the best so far, saving model to ./training_dir/transformer.pt
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# be
# to
# or
# any
# the
# with
# party
# is
# 0 samples that are in test:
# 2 samples that are new:
# shartns
# woither
# --------------------------------------------------------------------------------
# step 7010 | loss 2.1324 | step time 114.37ms
# step 7020 | loss 1.6855 | step time 117.17ms
# step 7030 | loss 1.3041 | step time 117.54ms
# step 7040 | loss 2.3483 | step time 116.31ms
# step 7050 | loss 1.2659 | step time 117.77ms
# step 7060 | loss 1.2541 | step time 119.00ms
# step 7070 | loss 1.4726 | step time 112.86ms
# step 7080 | loss 1.5832 | step time 113.84ms
# step 7090 | loss 1.1421 | step time 115.50ms
# step 7100 | loss 1.5257 | step time 116.03ms
# step 7110 | loss 1.3494 | step time 117.18ms
# step 7120 | loss 1.2609 | step time 118.72ms
# step 7130 | loss 1.4791 | step time 117.09ms
# step 7140 | loss 0.8735 | step time 116.58ms
# step 7150 | loss 1.0281 | step time 118.49ms
# step 7160 | loss 1.1713 | step time 116.30ms
# step 7170 | loss 0.8822 | step time 115.79ms
# step 7180 | loss 1.3219 | step time 117.71ms
# step 7190 | loss 2.1924 | step time 117.03ms
# step 7200 | loss 1.5544 | step time 114.93ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# its
# pur
# agreement
# it
# below
# inc
# a
# other
# 0 samples that are in test:
# 2 samples that are new:
# partied
# whas
# --------------------------------------------------------------------------------
# step 7210 | loss 1.0879 | step time 116.92ms
# step 7220 | loss 0.8850 | step time 118.38ms
# step 7230 | loss 1.1348 | step time 116.09ms
# step 7240 | loss 1.1419 | step time 117.09ms
# step 7250 | loss 1.1497 | step time 115.83ms
# step 7260 | loss 0.9613 | step time 120.43ms
# step 7270 | loss 1.0581 | step time 119.56ms
# step 7280 | loss 1.4813 | step time 123.53ms
# step 7290 | loss 1.3311 | step time 123.12ms
# step 7300 | loss 1.7980 | step time 117.69ms
# step 7310 | loss 1.4209 | step time 114.78ms
# step 7320 | loss 1.6024 | step time 117.57ms
# step 7330 | loss 1.7649 | step time 118.62ms
# step 7340 | loss 2.1097 | step time 117.97ms
# step 7350 | loss 1.7345 | step time 118.92ms
# step 7360 | loss 1.6843 | step time 117.14ms
# step 7370 | loss 1.0934 | step time 117.06ms
# step 7380 | loss 1.5405 | step time 114.53ms
# step 7390 | loss 1.8527 | step time 116.25ms
# step 7400 | loss 1.1400 | step time 115.75ms
# --------------------------------------------------------------------------------
# 5 samples that are in train:
# of
# to
# not
# der
# trust
# 0 samples that are in test:
# 5 samples that are new:
# noticy
# inters
# obligatimend
# porse
# agreemende
# --------------------------------------------------------------------------------
# step 7410 | loss 1.0366 | step time 116.58ms
# step 7420 | loss 1.2563 | step time 118.74ms
# step 7430 | loss 1.3116 | step time 115.84ms
# step 7440 | loss 1.8674 | step time 116.98ms
# step 7450 | loss 0.9814 | step time 118.06ms
# step 7460 | loss 1.2514 | step time 117.85ms
# step 7470 | loss 1.2439 | step time 117.05ms
# step 7480 | loss 1.6965 | step time 117.80ms
# step 7490 | loss 1.1116 | step time 119.06ms
# step 7500 | loss 1.4093 | step time 113.14ms
# step 7500 train loss: 1.4271855354309082 test loss: 1.530150055885315
# step 7510 | loss 1.2888 | step time 119.34ms
# step 7520 | loss 1.2298 | step time 117.16ms
# step 7530 | loss 1.8558 | step time 116.34ms
# step 7540 | loss 1.0147 | step time 116.76ms
# step 7550 | loss 1.0547 | step time 117.87ms
# step 7560 | loss 1.4900 | step time 117.65ms
# step 7570 | loss 1.8019 | step time 116.41ms
# step 7580 | loss 1.4285 | step time 117.74ms
# step 7590 | loss 1.4282 | step time 117.08ms
# step 7600 | loss 1.6002 | step time 119.56ms
# --------------------------------------------------------------------------------
# 10 samples that are in train:
# the
# parties
# purpose
# expected
# to
# party
# to
# the
# the
# a
# 0 samples that are in test:
# 0 samples that are new:
# --------------------------------------------------------------------------------
# step 7610 | loss 1.5260 | step time 116.45ms
# step 7620 | loss 1.8932 | step time 117.85ms
# step 7630 | loss 0.9180 | step time 119.05ms
# step 7640 | loss 1.0343 | step time 120.01ms
# step 7650 | loss 1.5496 | step time 116.30ms
# step 7660 | loss 0.9920 | step time 116.32ms
# step 7670 | loss 1.1499 | step time 117.06ms
# step 7680 | loss 1.6942 | step time 118.61ms
# step 7690 | loss 1.4830 | step time 121.05ms
# step 7700 | loss 1.1833 | step time 118.26ms
# step 7710 | loss 1.1838 | step time 118.79ms
# ...
# step 38790 | loss 0.8436 | step time 115.07ms
# step 38800 | loss 1.4077 | step time 116.55ms
# --------------------------------------------------------------------------------
# 10 samples that are in train:
# be
# the
# and
# and
# b
# ratings
# of
# the
# section
# rating
# 0 samples that are in test:
# 0 samples that are new:
# --------------------------------------------------------------------------------
# step 38810 | loss 0.8630 | step time 115.42ms
# step 38820 | loss 1.3487 | step time 117.29ms
# step 38830 | loss 1.1033 | step time 115.58ms
# step 38840 | loss 0.9262 | step time 113.30ms
# step 38850 | loss 1.4052 | step time 114.81ms
# step 38860 | loss 1.2096 | step time 118.04ms
# step 38870 | loss 0.8432 | step time 115.97ms
# step 38880 | loss 1.1586 | step time 118.37ms
# step 38890 | loss 0.7663 | step time 113.82ms
# step 38900 | loss 0.9372 | step time 113.48ms
# step 38910 | loss 0.7696 | step time 116.74ms
# step 38920 | loss 0.8836 | step time 117.59ms
# step 38930 | loss 0.9912 | step time 114.66ms
# step 38940 | loss 1.1554 | step time 115.92ms
# step 38950 | loss 0.8007 | step time 116.92ms
# step 38960 | loss 0.6569 | step time 114.69ms
# step 38970 | loss 1.1588 | step time 117.53ms
# step 38980 | loss 1.2381 | step time 116.36ms
# step 38990 | loss 1.8974 | step time 117.50ms
# step 39000 | loss 1.0172 | step time 115.08ms
# step 39000 train loss: 1.2258073091506958 test loss: 1.3288905620574951
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# party
# r
# a
# of
# that
# and
# party
# to
# 0 samples that are in test:
# 2 samples that are new:
# sucaa
# acted
# --------------------------------------------------------------------------------
# step 39010 | loss 1.1862 | step time 116.58ms
# step 39020 | loss 1.4592 | step time 114.72ms
# step 39030 | loss 1.8905 | step time 115.18ms
# step 39040 | loss 1.5518 | step time 115.86ms
# step 39050 | loss 0.7536 | step time 115.51ms
# step 39060 | loss 1.5131 | step time 116.64ms
# step 39070 | loss 0.9318 | step time 117.49ms
# step 39080 | loss 1.2605 | step time 113.73ms
# step 39090 | loss 1.1219 | step time 117.47ms
# step 39100 | loss 1.5323 | step time 114.78ms
# step 39110 | loss 1.2373 | step time 117.74ms
# step 39120 | loss 1.6667 | step time 115.97ms
# step 39130 | loss 0.8095 | step time 116.04ms
# step 39140 | loss 0.8480 | step time 116.56ms
# step 39150 | loss 1.2995 | step time 116.78ms
# step 39160 | loss 1.8248 | step time 115.85ms
# step 39170 | loss 1.0730 | step time 118.65ms
# step 39180 | loss 0.8927 | step time 117.10ms
# step 39190 | loss 0.8306 | step time 169.40ms
# step 39200 | loss 0.7920 | step time 114.13ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# s
# the
# i
# party
# debt
# event
# a
# a
# 0 samples that are in test:
# 2 samples that are new:
# signated
# designancy
# --------------------------------------------------------------------------------
# step 39210 | loss 1.3253 | step time 114.93ms
# step 39220 | loss 0.9004 | step time 116.20ms
# step 39230 | loss 1.2675 | step time 115.51ms
# step 39240 | loss 1.7843 | step time 116.25ms
# step 39250 | loss 0.8496 | step time 114.95ms
# step 39260 | loss 1.0786 | step time 116.26ms
# step 39270 | loss 1.3698 | step time 113.30ms
# step 39280 | loss 1.1973 | step time 115.17ms
# step 39290 | loss 1.8943 | step time 116.43ms
# step 39300 | loss 1.2860 | step time 116.67ms
# step 39310 | loss 1.3822 | step time 118.93ms
# step 39320 | loss 0.7826 | step time 115.16ms
# step 39330 | loss 0.8219 | step time 118.15ms
# step 39340 | loss 1.0043 | step time 117.63ms
# step 39350 | loss 1.6375 | step time 118.75ms
# step 39360 | loss 0.8794 | step time 116.16ms
# step 39370 | loss 0.9182 | step time 116.38ms
# step 39380 | loss 1.5149 | step time 115.37ms
# step 39390 | loss 2.0678 | step time 115.11ms
# step 39400 | loss 0.8087 | step time 116.01ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# in
# provider
# s
# such
# or
# b
# it
# of
# 0 samples that are in test:
# 2 samples that are new:
# provited
# santion
# --------------------------------------------------------------------------------
# step 39410 | loss 1.2634 | step time 116.38ms
# step 39420 | loss 1.0088 | step time 114.57ms
# step 39430 | loss 2.0070 | step time 114.80ms
# step 39440 | loss 0.9123 | step time 115.97ms
# step 39450 | loss 1.1592 | step time 115.48ms
# step 39460 | loss 1.2043 | step time 114.40ms
# step 39470 | loss 1.1696 | step time 116.02ms
# step 39480 | loss 0.9618 | step time 116.67ms
# step 39490 | loss 0.9840 | step time 113.01ms
# step 39500 | loss 1.1282 | step time 114.71ms
# step 39500 train loss: 1.1872786283493042 test loss: 1.297149419784546
# test loss 1.297149419784546 is the best so far, saving model to ./training_dir/transformer.pt
# step 39510 | loss 0.9750 | step time 119.84ms
# step 39520 | loss 1.2820 | step time 113.13ms
# step 39530 | loss 1.1930 | step time 115.07ms
# step 39540 | loss 0.8693 | step time 118.51ms
# step 39550 | loss 1.2535 | step time 115.20ms
# step 39560 | loss 0.8205 | step time 114.39ms
# step 39570 | loss 2.0962 | step time 115.10ms
# step 39580 | loss 1.3134 | step time 111.55ms
# step 39590 | loss 1.4686 | step time 116.79ms
# step 39600 | loss 1.1479 | step time 114.98ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# terms
# party
# at
# a
# terms
# that
# of
# and
# 0 samples that are in test:
# 2 samples that are new:
# agreemenc
# prhed
# --------------------------------------------------------------------------------
# step 39610 | loss 1.1351 | step time 115.67ms
# step 39620 | loss 1.2122 | step time 115.45ms
# step 39630 | loss 1.2532 | step time 114.93ms
# step 39640 | loss 1.5097 | step time 113.29ms
# step 39650 | loss 0.8030 | step time 115.60ms
# step 39660 | loss 0.9343 | step time 115.66ms
# step 39670 | loss 1.2811 | step time 115.43ms
# step 39680 | loss 0.9245 | step time 117.23ms
# step 39690 | loss 1.4947 | step time 114.58ms
# step 39700 | loss 1.2362 | step time 115.71ms
# step 39710 | loss 1.4585 | step time 114.81ms
# step 39720 | loss 2.4086 | step time 115.20ms
# step 39730 | loss 1.2041 | step time 116.19ms
# step 39740 | loss 1.9996 | step time 114.37ms
# step 39750 | loss 1.7101 | step time 116.39ms
# step 39760 | loss 1.4491 | step time 116.98ms
# step 39770 | loss 0.9362 | step time 114.04ms
# step 39780 | loss 1.0089 | step time 115.57ms
# step 39790 | loss 0.9170 | step time 136.34ms
# step 39800 | loss 1.2336 | step time 116.20ms
# --------------------------------------------------------------------------------
# 10 samples that are in train:
# a
# this
# company
# at
# the
# as
# clause
# a
# s
# of
# 0 samples that are in test:
# 0 samples that are new:
# --------------------------------------------------------------------------------
# step 39810 | loss 0.7549 | step time 116.85ms
# step 39820 | loss 1.0203 | step time 119.35ms
# step 39830 | loss 1.4557 | step time 114.28ms
# step 39840 | loss 1.2918 | step time 118.40ms
# step 39850 | loss 1.0853 | step time 115.72ms
# step 39860 | loss 0.9742 | step time 117.76ms
# step 39870 | loss 0.8744 | step time 115.14ms
# step 39880 | loss 1.8198 | step time 116.78ms
# step 39890 | loss 1.3673 | step time 119.31ms
# step 39900 | loss 1.5992 | step time 116.21ms
# step 39910 | loss 0.9837 | step time 116.72ms
# step 39920 | loss 1.1971 | step time 115.55ms
# step 39930 | loss 1.1401 | step time 117.73ms
# step 39940 | loss 0.8630 | step time 117.37ms
# step 39950 | loss 0.7740 | step time 115.70ms
# step 39960 | loss 1.8686 | step time 115.31ms
# step 39970 | loss 1.4003 | step time 116.35ms
# step 39980 | loss 1.9366 | step time 117.07ms
# step 39990 | loss 1.3315 | step time 114.92ms
# step 40000 | loss 1.1023 | step time 115.96ms
# step 40000 train loss: 1.2550197839736938 test loss: 1.391945719718933
# --------------------------------------------------------------------------------
# 9 samples that are in train:
# the
# on
# the
# as
# any
# the
# date
# to
# and
# 0 samples that are in test:
# 1 samples that are new:
# purstanding
# --------------------------------------------------------------------------------
# step 40010 | loss 1.3216 | step time 116.10ms
# step 40020 | loss 1.4751 | step time 117.30ms
# step 40030 | loss 1.4588 | step time 118.79ms
# step 40040 | loss 1.1921 | step time 115.15ms
# step 40050 | loss 1.7066 | step time 115.55ms
# step 40060 | loss 0.8459 | step time 117.96ms
# step 40070 | loss 1.7554 | step time 115.43ms
# step 40080 | loss 1.0042 | step time 114.12ms
# step 40090 | loss 1.0724 | step time 115.09ms
# step 40100 | loss 1.0685 | step time 116.35ms
# step 40110 | loss 1.4003 | step time 117.69ms
# step 40120 | loss 1.4563 | step time 117.66ms
# step 40130 | loss 1.5977 | step time 116.59ms
# step 40140 | loss 1.0875 | step time 116.42ms
# step 40150 | loss 1.0307 | step time 115.80ms
# step 40160 | loss 1.1149 | step time 116.55ms
# step 40170 | loss 0.6268 | step time 114.94ms
# step 40180 | loss 1.2932 | step time 113.13ms
# step 40190 | loss 0.7659 | step time 119.73ms
# step 40200 | loss 0.8218 | step time 116.77ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# the
# or
# provided
# of
# b
# the
# any
# 0 samples that are in test:
# 3 samples that are new:
# orr
# wither
# thy
# --------------------------------------------------------------------------------
# step 40210 | loss 1.7236 | step time 117.51ms
# step 40220 | loss 1.5741 | step time 116.53ms
# step 40230 | loss 0.9867 | step time 118.41ms
# step 40240 | loss 0.7891 | step time 117.00ms
# step 40250 | loss 1.5706 | step time 118.46ms
# step 40260 | loss 1.1541 | step time 119.15ms
# step 40270 | loss 1.1184 | step time 117.31ms
# step 40280 | loss 1.0405 | step time 117.17ms
# step 40290 | loss 0.7541 | step time 117.79ms
# step 40300 | loss 0.9646 | step time 118.34ms
# step 40310 | loss 1.0572 | step time 115.04ms
# step 40320 | loss 1.0857 | step time 116.54ms
# step 40330 | loss 0.8997 | step time 118.36ms
# step 40340 | loss 1.2659 | step time 116.40ms
# step 40350 | loss 1.2086 | step time 117.81ms
# step 40360 | loss 1.0224 | step time 119.19ms
# step 40370 | loss 0.9783 | step time 120.35ms
# step 40380 | loss 1.8170 | step time 115.92ms
# step 40390 | loss 1.4436 | step time 117.28ms
# step 40400 | loss 1.2885 | step time 116.09ms
# --------------------------------------------------------------------------------
# 10 samples that are in train:
# or
# that
# a
# party
# a
# section
# section
# a
# senior
# to
# 0 samples that are in test:
# 0 samples that are new:
# --------------------------------------------------------------------------------
# step 40410 | loss 1.2505 | step time 116.23ms
# step 40420 | loss 1.1065 | step time 117.03ms
# step 40430 | loss 1.2763 | step time 116.92ms
# step 40440 | loss 2.1120 | step time 117.27ms
# step 40450 | loss 1.4967 | step time 118.87ms
# step 40460 | loss 1.2253 | step time 116.44ms
# step 40470 | loss 1.8068 | step time 115.56ms
# step 40480 | loss 1.1262 | step time 115.82ms
# step 40490 | loss 1.1396 | step time 116.68ms
# step 40500 | loss 1.4736 | step time 118.35ms
# step 40500 train loss: 1.1606634855270386 test loss: 1.2792081832885742
# test loss 1.2792081832885742 is the best so far, saving model to ./training_dir/transformer.pt
# step 40510 | loss 0.6777 | step time 120.14ms
# step 40520 | loss 1.1080 | step time 116.45ms
# step 40530 | loss 1.7185 | step time 117.90ms
# step 40540 | loss 1.4741 | step time 117.99ms
# step 40550 | loss 0.7619 | step time 114.92ms
# step 40560 | loss 1.1659 | step time 117.06ms
# step 40570 | loss 0.8033 | step time 116.07ms
# step 40580 | loss 0.7903 | step time 117.15ms
# step 40590 | loss 1.1125 | step time 114.79ms
# step 40600 | loss 1.7641 | step time 118.83ms
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# ac
# party
# party
# the
# be
# of
# of
# section
# 0 samples that are in test:
# 2 samples that are new:
# excult
# share
# --------------------------------------------------------------------------------
# step 40610 | loss 1.1051 | step time 113.08ms
# step 40620 | loss 1.2094 | step time 116.73ms
# step 40630 | loss 1.0336 | step time 115.82ms
# step 40640 | loss 1.2833 | step time 116.41ms
# step 40650 | loss 1.9314 | step time 116.60ms
# step 40660 | loss 1.0286 | step time 117.25ms
# step 40670 | loss 0.7624 | step time 116.35ms
# step 40680 | loss 0.8099 | step time 118.00ms
# step 40690 | loss 1.5977 | step time 117.50ms
# step 40700 | loss 0.8936 | step time 116.58ms
# step 40710 | loss 1.0106 | step time 120.70ms
# step 40720 | loss 1.0623 | step time 116.91ms
# step 40730 | loss 0.8727 | step time 118.84ms
# step 40740 | loss 1.3846 | step time 118.79ms
# step 40750 | loss 1.4256 | step time 118.06ms
# step 40760 | loss 1.1090 | step time 118.06ms
# step 40770 | loss 1.4399 | step time 116.16ms
# step 40780 | loss 1.0085 | step time 116.06ms
# step 40790 | loss 1.0551 | step time 114.92ms
# step 40800 | loss 0.8308 | step time 116.89ms
# --------------------------------------------------------------------------------
# 7 samples that are in train:
# is
# the
# party
# or
# b
# as
# of
# 0 samples that are in test:
# 3 samples that are new:
# actaoted
# sirlsfaced
# reprcedingssesati
# --------------------------------------------------------------------------------
# step 40810 | loss 0.9746 | step time 114.59ms
# step 40820 | loss 1.0786 | step time 116.50ms
# step 40830 | loss 1.8209 | step time 116.77ms
# step 40840 | loss 1.4952 | step time 118.88ms
# step 40850 | loss 1.0399 | step time 117.62ms
# step 40860 | loss 0.9946 | step time 117.04ms
# step 40870 | loss 1.8192 | step time 116.16ms
# step 40880 | loss 1.1936 | step time 117.72ms
# step 40890 | loss 1.6667 | step time 115.11ms
# step 40900 | loss 0.7922 | step time 119.67ms
# step 40910 | loss 1.4486 | step time 115.64ms
# step 40920 | loss 1.7642 | step time 116.17ms
# step 40930 | loss 0.7465 | step time 118.26ms
# step 40940 | loss 1.1803 | step time 120.08ms
# step 40950 | loss 0.9274 | step time 122.11ms
# step 40960 | loss 1.1183 | step time 120.60ms
# step 40970 | loss 1.6789 | step time 112.93ms
# step 40980 | loss 1.5400 | step time 119.75ms
# step 40990 | loss 0.9626 | step time 121.29ms
# step 41000 | loss 1.7774 | step time 115.64ms
# step 41000 train loss: 1.1909773349761963 test loss: 1.302939772605896
# --------------------------------------------------------------------------------
# 8 samples that are in train:
# period
# are
# agreement
# e
# agreement
# a
# of
# b
# 0 samples that are in test:
# 2 samples that are new:
# agreemency
# suec
# --------------------------------------------------------------------------------
# step 41010 | loss 1.6901 | step time 122.97ms
# step 41020 | loss 1.3959 | step time 185.01ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 39
#      37 # calculate the gradient, update the weights
#      38 transformer.zero_grad(set_to_none=True)
# ---> 39 loss.backward()
#      40 optimizer.step()
#      42 t1 = time.time()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
@torch.no_grad()
def generate_infinite(model, dataset, device='cpu', max_new_tokens_per_word=100):
    """
    Generate words infinitely in real time using the transformer model.
    Each word is generated and printed as it's completed.
    
    Args:
        model: Trained transformer model
        dataset: CharDataset for decoding
        device: Device to run on ('cpu', 'cuda', 'mps', or torch.device)
        max_new_tokens_per_word: Maximum tokens to generate per word
    """
    # Handle device specification
    if isinstance(device, str):
        # Check if device is available
        if device == 'mps' and not torch.backends.mps.is_available():
            print("MPS not available, falling back to CPU")
            device = 'cpu'
        elif device == 'cuda' and not torch.cuda.is_available():
            print("CUDA not available, falling back to CPU")
            device = 'cpu'
        device = torch.device(device)
    
    model = model.to(device)
    model.eval()
    block_size = model.block_size
    word_count = 0
    
    print(f"Generating on device: {device}")
    
    try:
        while True:
            # Initialize with START token (index 0) on the specified device
            idx = torch.zeros((1, 1), dtype=torch.long, device=device)
            word_chars = []
            
            # Generate one word
            for token_pos in range(max_new_tokens_per_word):
                # Crop sequence to block_size if needed
                idx_cond = idx if idx.size(1) <= block_size else idx[:, -block_size:]
                
                # Forward pass
                logits, _ = model(idx_cond)
                
                # Get next token probabilities from last position
                logits = logits[:, -1, :]  # (1, vocab_size)
                probs = F.softmax(logits, dim=-1)
                
                # Sample next token
                idx_next = torch.multinomial(probs, num_samples=1)  # (1, 1)
                idx = torch.cat((idx, idx_next), dim=1)  # (1, T+1)
                
                next_token = int(idx_next.item())
                
                # Stop token (index 0) ends the word
                if next_token == 0:
                    break
                
                # Decode and accumulate character
                char = dataset.itos[next_token]
                word_chars.append(char)
            
            # Print completed word
            word = ''.join(word_chars)
            if word:  # Only print non-empty words
                word_count += 1
                print(f"{word_count}. {word}")
    
    except KeyboardInterrupt:
        print(f"\n\nGeneration stopped. Generated {word_count} words.")

# Determine device (MPS for Apple Silicon, CUDA for NVIDIA, CPU as fallback)
if torch.backends.mps.is_available():
    device = 'mps'
    print("Using MPS (Metal Performance Shaders)")
elif torch.cuda.is_available():
    device = 'cuda'
    print("Using CUDA")
else:
    device = 'cpu'
    print("Using CPU")

# Run infinite generation (press Ctrl+C to stop)
generate_infinite(transformer, train_dataset, device=device)
# Out:
# Using MPS (Metal Performance Shaders)
# Generating on device: mps
# 1. deliverr
# 2. for
# 3. with
# 4. and
# 5. for
# 6. takeng
# 7. a
# 8. party
# 9. in
# 10. of
# 11. each
# 12. ofdgcer
# 13. in
# 14. a
# 15. and
# 16. a
# 17. solely
# 18. upon
# 19. in
# 20. respect
# 21. a
# 22. to
# 23. for
# 24. b
# 25. of
# 26. year
# 27. the
# 28. molth
# 29. pursuant
# 30. a
# 31. 30
# 32. and
# 33. deendule
# 34. in
# 35. by
# 36. period
# 37. for
# 38. other
# 39. thres
# 40. in
# 41. or
# 42. behalf
# 43. capacy
# 44. no
# 45. provided
# 46. its
# 47. such
# 48. undngs
# 49. counterparty
# 50. support
# 51. a
# 52. unsa
# 53. transaction
# 54. of
# 55. imfeenay
# 56. each
# 57. a
# 58. apply
# 59. payment
# 60. as
# 61. sameshold
# 62. the
# 63. party
# 64. to
# 65. w
# 66. prevident
# 67. a
# 68. condinions
# 69. 4
# 70. substitute
# 71. other
# 72. will
# 73. assent
# 74. potter
# 75. deternal
# 76. relied
# 77. specified
# 78. a
# 79. a
# 80. in
# 81. or
# 82. its
# 83. facsimile
# 84. of
# 85. and
# 86. waxng
# 87. party
# 88. the
# 89. under
# 90. not
# 91. discsion
# 92. bld
# 93. will
# 94. v3
# 95. in
# 96. be
# 97. not
# 98. and
# 99. of
# 100. inrevupt
# 101. by
# 102. for
# 103. or
# 104. sames
# 105. obligations
# 106. condition
# 107. rating
# 108. respect
# 109. in
# 110. determine
# 111. the
# 112. has
# 113. bank
# 114. be
# 115. to
# 116. in
# 117. party
# 118. b
# 119. this
# 120. party
# 121. to
# 122. has
# 123. period
# 124. b
# 125. only
# 126. 36
# 127. party
# 128. of
# 129. ii
# 130. each
# 131. agneemence
# 132. mader
# 133. ondgunder
# 134. woulseel
# 135. be
#
#
# Generation stopped. Generated 135 words.
